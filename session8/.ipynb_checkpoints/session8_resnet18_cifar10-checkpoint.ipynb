# %% [markdown]
# # EVA5 Session 8 Assignment by Sachin Dangayach
#
# **Receptive Fields & Network Architectures**
#
# ** Target**
# 1.  Go through this repository: https://github.com/kuangliu/pytorch-cifar
#
# 2.  Extract the ResNet18 model from this repository and add it to your API/repo
#
# 3.  Target is 85% accuracy. No limit on the number of epochs. Use default ResNet18 code (so params are fixed).
#
#
# **B. Results**
#
# 1.  Parameters: 11,173,962
# 2.  Best Training Accuracy in 20 epochs: 95.73%
# 3.  Best Test Accuracy in 20 epochs: 85.59 %
#
#
# **C. Analysis**
#
# Model gets the desired accuracy in 10 epochs. There is training and testing accuracy gap is there. I used L2 regularizer to reduce the gap along with images transformations like rotations and horizontal shift. Gap is reduced but still scope of improvement is there.

# %%
import torch
import torch.optim as optim

from torchsummary import summary
from torch.optim.lr_scheduler import StepLR

# %%
# !git clone https://github.com/SachinDangayach/TSAI_EVA5.git
# Out:
# fatal: destination path 'TSAI_EVA5' already exists and is not an empty directory.

# %%
from TSAI_EVA5.session8.dataset import session7_dataset as dataset
from TSAI_EVA5.session8.models import session8_resnet18_model as models
from TSAI_EVA5.session8.models import session8_train_model as train
from TSAI_EVA5.session8.models import session8_test_model as test
from TSAI_EVA5.session8.utils import session7_utils as utils

# %% [markdown]
# ## Extract, Load and Transform Data

# %%
# Calculate Ture Mean and STD
norm_mean,norm_std = dataset.cifar10_mean_std() #  (0.49, 0.48, 0.45), (0.25, 0.24, 0.26)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Get train and test transform
train_transform, test_transform = dataset.get_transforms(norm_mean,norm_std)
# Out:
# (0.49, 0.48, 0.45) (0.25, 0.24, 0.26)

# %%
# Extract and transform the data
train_set,test_set = dataset.get_datasets(train_transform,test_transform)

# Targets -> ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
classes = train_set.classes

# Dataloader Arguments & Test/Train Dataloaders - Load part of ETL
train_loader,test_loader = dataset.get_dataloaders(train_set,test_set)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True

# %% [markdown]
# ### Data Exploration

# %%
# Explore sample images
utils.show_sample_images(train_loader, classes, .5, .25, num_of_images = 10)
# Out:
# Displaying 10 images
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Import Model and show model summary

# %%
# Model summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = models.ResNet18().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %% [markdown]
# ## Train and Test Model

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train.train(model, device, train_loader, optimizer, epoch, train_losses, train_acc)
    scheduler.step()
    test.test(model, device, test_loader, test_losses, test_acc)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.600549340248108 Batch_id=390 Train Accuracy=35.54: 100%|██████████| 391/391 [01:01<00:00,  6.40it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.4434, Test Accuracy: 4592/10000 (45.92%)
#
# EPOCH: 1
# Loss=1.3038063049316406 Batch_id=390 Train Accuracy=52.98: 100%|██████████| 391/391 [01:02<00:00,  6.26it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.2128, Test Accuracy: 5621/10000 (56.21%)
#
# EPOCH: 2
# Loss=0.8020457029342651 Batch_id=390 Train Accuracy=62.26: 100%|██████████| 391/391 [01:02<00:00,  6.26it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.9742, Test Accuracy: 6566/10000 (65.66%)
#
# EPOCH: 3
# Loss=0.8444452285766602 Batch_id=390 Train Accuracy=70.24: 100%|██████████| 391/391 [01:02<00:00,  6.27it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.9058, Test Accuracy: 6925/10000 (69.25%)
#
# EPOCH: 4
# ...

# %% [markdown]
# #  Validation accuracies and Loss change curves

# %%
utils.valid_accuracy_loss_plots(train_losses, train_acc, test_losses, test_acc)

# %% [markdown]
# ## Display misclassified images

# %%
utils.show_misclassified_images(model, classes, test_loader, num_of_images = 29)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
